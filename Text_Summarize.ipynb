Reader apparently left the images "scattered on the floor of the vault" for the police to find.

There has been no evidence this was true.

Another rumour was that the government imposed a "D-notice" - now called a DSMA-notice - on the story.

This hinges on a lack of coverage of the story, with many claiming it disappeared from the news agenda.

A DSMA-notice is issued to prevent inadvertent public disclosure of information that would compromise UK military and intelligence operations.

It is not usually used to silence news stories about bank jobs that have already happened.

The lack of published stories, though, isn't quite true. Naturally, interest died down, but the raid was still being reported in national and regional papers throughout the decade.

The rumour may have started with radio ham Mr Rowlands, who said police had snatched a phone out of his grasp while he spoke to a newspaper about his part in the case.

He said the officer had told the editor he was not allowed to publish anything.

Years later, Mr Rowlands suggested the police were trying to cover up what appeared to be their own incompetence.

The only mystery that remains is what is in the 800 pages of sealed documents at the National Archives. They are due to be released in 47 years time.

So what did Lloyds Bank say about the whole event?

It advised customers to insure valuables kept in their safety boxes and denied any liability.

After all, it said: "It is a little unusual for raiders to come up through the floor."
"""

# %%
import textwrap

def chunk_text(text, max_tokens=450):
    """Splits text into chunks that fit within the model's token limit."""
    sentences = text.split(". ")
    chunks, current_chunk = [], ""

    for sentence in sentences:
        if len(tokenizer(current_chunk + sentence)["input_ids"]) < max_tokens:
            current_chunk += sentence + ". "
        else:
            chunks.append(current_chunk.strip())
            current_chunk = sentence + ". "

    if current_chunk:
        chunks.append(current_chunk.strip())

    return chunks

def summarize(text):
    chunks = chunk_text(text)
    summaries = []

    for chunk in chunks:
        inputs = tokenizer(chunk, return_tensors="pt", truncation=True, padding="longest")
        summary_ids = model.generate(**inputs, max_length=150, num_beams=5, early_stopping=True)
        summaries.append(tokenizer.decode(summary_ids[0], skip_special_tokens=True))

    return " ".join(summaries)

# Example Usage
long_text = text
summary = summarize(long_text)
print("Summary:", summary)
# Out:
# Summary: In autumn of 1971, a group of men carried out one of the most astonishing bank raids in history .<n> Skill, audacity and patience, criminal connections, a fair amount of luck, and inspiration from a Sherlock Holmes story culminated in a weekend of high drama .<n>Amateur radio operator was all the time being listened to by an amateur radio operator who was trying to tune in to pirate radio . The vibrations caused by the work led to businesses' trembler alarms repeatedly going off .<n>Four people, including Wolfe and Anthony Gavin, were jailed in 1973 .<n>It's thought at least another four, including a woman, slipped away . It was reported that it could be anything between £500,000 and £3m .<n>Only a fraction was recovered, and the rest went untracked .<n>There were rumours involving government suppression of the story .<n>Records about it officially sealed at the national archives until 2071 . Scotland Yard called in a detection van from the Post Office in an attempt to trace the walkie-talkie signal .<n>But they didn't do this until Sunday afternoon, when it was all over . Gavin, Tucker and Stephen pleaded guilty to entering the bank as a trespasser, stealing cash and jewellery and possessing explosives .<n>Wolfe was given eight years in jail, while the others received 12 . Bank vault raid was reported in national and regional papers throughout the decade .<n>The rumour may have started with radio ham Mr Rowlands, who said police had snatched a phone out of his grasp while he spoke to a newspaper .

# %%
data = summary.split("<n>")
data
# Out:
# ['In autumn of 1971, a group of men carried out one of the most astonishing bank raids in history .',
#  ' Skill, audacity and patience, criminal connections, a fair amount of luck, and inspiration from a Sherlock Holmes story culminated in a weekend of high drama .',
#  "Amateur radio operator was all the time being listened to by an amateur radio operator who was trying to tune in to pirate radio . The vibrations caused by the work led to businesses' trembler alarms repeatedly going off .",
#  'Four people, including Wolfe and Anthony Gavin, were jailed in 1973 .',
#  "It's thought at least another four, including a woman, slipped away . It was reported that it could be anything between £500,000 and £3m .",
#  'Only a fraction was recovered, and the rest went untracked .',
#  'There were rumours involving government suppression of the story .',
#  'Records about it officially sealed at the national archives until 2071 . Scotland Yard called in a detection van from the Post Office in an attempt to trace the walkie-talkie signal .',
#  "But they didn't do this until Sunday afternoon, when it was all over . Gavin, Tucker and Stephen pleaded guilty to entering the bank as a trespasser, stealing cash and jewellery and possessing explosives .",
#  'Wolfe was given eight years in jail, while the others received 12 . Bank vault raid was reported in national and regional papers throughout the decade .',
#  'The rumour may have started with radio ham Mr Rowlands, who said police had snatched a phone out of his grasp while he spoke to a newspaper .']

# %%
len(text), len(summary)
# Out:
# (9990, 1523)

# %%
len(summary)/len(text)
# Out:
# 0.15245245245245245

# %%
import textwrap

def chunk_text(text, max_tokens=450):
    """Splits text into chunks that fit within the model's token limit."""
    sentences = text.split(". ")
    chunks, current_chunk = [], ""

    for sentence in sentences:
        if len(tokenizer(current_chunk + sentence)["input_ids"]) < max_tokens:
            current_chunk += sentence + ". "
        else:
            chunks.append(current_chunk.strip())
            current_chunk = sentence + ". "

    if current_chunk:
        chunks.append(current_chunk.strip())

    return chunks

def summarize(text):
    chunks = chunk_text(text)
    summaries = []

    for chunk in chunks:
        inputs = tokenizer(chunk, return_tensors="pt", truncation=True, padding="longest")
        summary_ids = model.generate(**inputs, max_length=200, num_beams=5, early_stopping=True)
        summaries.append(tokenizer.decode(summary_ids[0], skip_special_tokens=True))

    return " ".join(summaries)

# Example Usage
long_text = text
summary = summarize(long_text)
print("Summary:", summary)
# Out:
# Summary: In autumn of 1971, a group of men carried out one of the most astonishing bank raids in history .<n> Skill, audacity and patience, criminal connections, a fair amount of luck, and inspiration from a Sherlock Holmes story culminated in a weekend of high drama .<n>Amateur radio operator was all the time being listened to by an amateur radio operator who was trying to tune in to pirate radio . The vibrations caused by the work led to businesses' trembler alarms repeatedly going off .<n>Four people, including Wolfe and Anthony Gavin, were jailed in 1973 .<n>It's thought at least another four, including a woman, slipped away . It was reported that it could be anything between £500,000 and £3m .<n>Only a fraction was recovered, and the rest went untracked .<n>There were rumours involving government suppression of the story .<n>Records about it officially sealed at the national archives until 2071 . Scotland Yard called in a detection van from the Post Office in an attempt to trace the walkie-talkie signal .<n>But they didn't do this until Sunday afternoon, when it was all over . Gavin, Tucker and Stephen pleaded guilty to entering the bank as a trespasser, stealing cash and jewellery and possessing explosives .<n>Wolfe was given eight years in jail, while the others received 12 . Bank vault raid was reported in national and regional papers throughout the decade .<n>The rumour may have started with radio ham Mr Rowlands, who said police had snatched a phone out of his grasp while he spoke to a newspaper .

# %%
data = summary.split("<n>")
data
# Out:
# ['In autumn of 1971, a group of men carried out one of the most astonishing bank raids in history .',
#  ' Skill, audacity and patience, criminal connections, a fair amount of luck, and inspiration from a Sherlock Holmes story culminated in a weekend of high drama .',
#  "Amateur radio operator was all the time being listened to by an amateur radio operator who was trying to tune in to pirate radio . The vibrations caused by the work led to businesses' trembler alarms repeatedly going off .",
#  'Four people, including Wolfe and Anthony Gavin, were jailed in 1973 .',
#  "It's thought at least another four, including a woman, slipped away . It was reported that it could be anything between £500,000 and £3m .",
#  'Only a fraction was recovered, and the rest went untracked .',
#  'There were rumours involving government suppression of the story .',
#  'Records about it officially sealed at the national archives until 2071 . Scotland Yard called in a detection van from the Post Office in an attempt to trace the walkie-talkie signal .',
#  "But they didn't do this until Sunday afternoon, when it was all over . Gavin, Tucker and Stephen pleaded guilty to entering the bank as a trespasser, stealing cash and jewellery and possessing explosives .",
#  'Wolfe was given eight years in jail, while the others received 12 . Bank vault raid was reported in national and regional papers throughout the decade .',
#  'The rumour may have started with radio ham Mr Rowlands, who said police had snatched a phone out of his grasp while he spoke to a newspaper .']

# %%
len(text), len(summary)
# Out:
# (9990, 1523)

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration

# Other T5 MODEL NAMES (t5-small, t5-base, t5-large, t5-3b, t5-11b)
model_name = "t5-large"
tokenizer = T5Tokenizer.from_pretrained(model_name)
model = T5ForConditionalGeneration.from_pretrained(model_name)
# Out:
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# model.safetensors:   0%|          | 0.00/2.95G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %%
def chunk_text(text, max_tokens=450):
    """Splits text into smaller chunks that fit within the token limit."""
    sentences = text.split(". ")
    chunks, current_chunk = [], ""

    for sentence in sentences:
        if len(tokenizer(current_chunk + sentence)["input_ids"]) < max_tokens:
            current_chunk += sentence + ". "
        else:
            chunks.append(current_chunk.strip())
            current_chunk = sentence + ". "

    if current_chunk:
        chunks.append(current_chunk.strip())

    return chunks

# %%
def summarize_long_text(text):
    chunks = chunk_text(text)
    summaries = []

    for chunk in chunks:
        prompt = "summarize like a narrative " + chunk
        inputs = tokenizer(prompt, return_tensors="pt", truncation=True, max_length=512)

        summary_ids = model.generate(
            **inputs, max_length=300, num_beams=5, temperature=0.7, early_stopping=True
        )

        summaries.append(tokenizer.decode(summary_ids[0], skip_special_tokens=True))

    return " ".join(summaries)

# %%
long_text = text

summary = summarize_long_text(long_text)
print("Summary:", summary)
# Out:
# Summary: . It reads, and there had been a number of that reads that reads a story that reads, a group of men came together who would carry out one of the most astonishing bank raids in history. and in a of in which a gang tunnelled into a secure vault and made in which in which police were on one side while the gang were and and. A weekend in which and a a narrative how the gang got away with the heist and how many people were involved. read like a narrative The vibrations caused by the work led to businesses' trembler alarms repeatedly going off. so the businesses disabled their trembler alarms. read. going off.... the gang was and to have been or, and, and,,,, -. There were rumours about government suppression of the story, for reasons unknown. It was reported that it could be anything between £500,000 and £3m (today's equivalent of £6m and £40m). Only a fraction was recovered, and the rest went untracked . and is there any truth to the claim that one box contained photographs of Princess Margaret in an intimate clinch? police called in a detection van from the post office in an attempt to trace the walkie-talkie signal . detectives didn't trace the signal until Sunday afternoon, when it was all over . the biggest robbery ever carried out in the metropolitan police district, with 120 detectives working on the case . . "It is, based on the heist. "It is,,,- and, stealing cash and jewellery and possessing explosives. Wolfe pleaded guilty to entering the bank as a trespasser, stealing cash and jewellery and possessing explosives..: " would be very high and the penalty for failure was given eight years in jail, while the others received 12. said said and . The storyline reads - now called a DSMA-notice - and what is in the 800 pages of sealed documents at the National Archives. It reads, that reads that reads in which the British Security Services want to retrieve some compromising photographs of Princess Margaret, allegedly held in a security box by Trinidadian militant gangster Michael X. was to get a gang to tunnel into the vault. boosted that that in they read . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .

# %%
data = summary.split(".")
data
# Out:
# ['in 1971, a gang tunnelled into a vault and made off with the contents of hundreds of secure deposit boxes ',
#  " police were on one side of the vault's door while the gang were on the other, and nobody thought to check inside ",
#  ' this is the story of how one of the most secure locations in the country was plundered ',
#  " the vibrations caused by the work led to businesses' trembler alarms repeatedly going off ",
#  ' so the businesses disabled their trembler alarms ',
#  ' originally thought to have been organised by a Brian Reader, who was later involved in both the Brinks-Mat heist and the Hatton garden raid ',
#  ' gang dug a 40ft tunnel through the roof of a leather shop in london ',
#  ' they used a 100-tonne jack, explosives and a thermal lance to break in ',
#  " a lookout on a ham radio picked up the gang's walkie-talkie conversations ",
#  ' only a fraction was recovered, and the rest went untracked ',
#  ' police call in a detection van from the post office in an attempt to trace the walkie-talkie signal ',
#  " but they didn't do this until Sunday afternoon, when it was all over ",
#  ' it was the biggest robbery ever carried out in the metropolitan police district ',
#  ' the tunnel-digging was described at the Old Bailey as "a magnificent piece of engineering" judge sutcliffe QC said he was passing a lesser sentence on Wolfe because of his age ',
#  ' the heist was the inspiration for a 2008 film, the bank job ',
#  ' british security services want to retrieve compromising photographs of princess Margaret ',
#  ' the obvious solution was to get a gang to tunnel into the vault ',
#  ' the storyline boosted a rumour that appeared in newspapers ',
#  ' Lloyds bank advises customers to insure valuables kept in safety boxes ',
#  ' it denies any liability and says it is "a little unusual for raiders to come up through the floor',
#  '"']

# %%
len(text), len(summary)
# Out:
# (9990, 1762)

# %%
data = summary.split(".")
data
# Out:
# ['',
#  ' It reads, and there had been a number of that reads that reads a story that reads, a group of men came together who would carry out one of the most astonishing bank raids in history',
#  ' and in a of in which a gang tunnelled into a secure vault and made in which in which police were on one side while the gang were and and',
#  ' A weekend in which and a a narrative how the gang got away with the heist and how many people were involved',
#  " read like a narrative The vibrations caused by the work led to businesses' trembler alarms repeatedly going off",
#  ' so the businesses disabled their trembler alarms',
#  ' read',
#  ' going off',
#  '',
#  '',
#  '',
#  ' the gang was and to have been or, and, and,,,, -',
#  ' There were rumours about government suppression of the story, for reasons unknown',
#  " It was reported that it could be anything between £500,000 and £3m (today's equivalent of £6m and £40m)",
#  ' Only a fraction was recovered, and the rest went untracked ',
#  ' and is there any truth to the claim that one box contained photographs of Princess Margaret in an intimate clinch? police called in a detection van from the post office in an attempt to trace the walkie-talkie signal ',
#  " detectives didn't trace the signal until Sunday afternoon, when it was all over ",
#  ' the biggest robbery ever carried out in the metropolitan police district, with 120 detectives working on the case ',
#  ' ',
#  ' "It is, based on the heist',
#  ' "It is,,,- and, stealing cash and jewellery and possessing explosives',
#  ' Wolfe pleaded guilty to entering the bank as a trespasser, stealing cash and jewellery and possessing explosives',
#  '',
#  ': " would be very high and the penalty for failure was given eight years in jail, while the others received 12',
#  ' said said and ',
#  ' The storyline reads - now called a DSMA-notice - and what is in the 800 pages of sealed documents at the National Archives',
#  ' It reads, that reads that reads in which the British Security Services want to retrieve some compromising photographs of Princess Margaret, allegedly held in a security box by Trinidadian militant gangster Michael X',
#  ' was to get a gang to tunnel into the vault',
#  ' boosted that that in they read ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '']
